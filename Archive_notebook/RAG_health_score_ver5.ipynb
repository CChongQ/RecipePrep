# %% [markdown]
# # Calculate Health Score Using RAG

# %%
# Dependencies are managed in pyproject.toml.

# %%
# Dependencies are managed in pyproject.toml.

# %%
# Dependencies are managed in pyproject.toml.

# %%
# Dependencies are managed in pyproject.toml.

# %%
# Set OPENAI_API_KEY in your environment before building the retriever.

# %%
from recipeprep.config import get_config
config = get_config()
config.ensure_output_directories()

# %%
import json
from recipeprep.nutrition import convert_to_grams, get_health_score_with_rag
from recipeprep.retrieval import build_nutrient_retriever, retrieve_food_and_nutrients

file_path = config.nutrient_map_path
retriever = build_nutrient_retriever(file_path)

# %%
print(retrieve_food_and_nutrients(retriever, "tomato"))

# %% [markdown]
# ## split documents into chunks for embedding and vector storage

# %%
# Text splitting and persistence are handled by build_nutrient_retriever().

# %%
# The persistent nutrient vector store is ready.

# %% [markdown]
# ## Retrieve

# %%
# Nutrient lookup is imported from recipeprep.retrieval.

# %% [markdown]
# ## Generate

# %%
# Safe quantity parsing and unit conversion are implemented in recipeprep.nutrition.

# %%
# Deterministic health scoring is imported from recipeprep.nutrition.

# %% [markdown]
# ### Test

# %%
file_path = config.processed_recipes_dir / "processed_recipes_init_200_batch_1.json"
with open(file_path,"r") as file:
  recipes=json.load(file)
recipe=recipes[1]
# print(recipe["processed_ingredients"])
# print(len(recipe["pure_ingredients"]))
print(get_health_score_with_rag(retriever,recipe))

# %% [markdown]
# ### Add `total_health_score` in JSON file

# %%
file_path = config.processed_recipes_dir / "processed_recipes_init_200_batch_3.json"
with open(file_path,"r") as file:
  recipes=json.load(file)

for i,recipe in enumerate(recipes):
  print(f"Recipe {i}")
  health_score,score_summary=get_health_score_with_rag(retriever,recipe)
  recipe["total_health_score"]=health_score
  recipe["summary_of_points"] = score_summary

output_file_path = config.datasets_dir / "scored_recipes_init_200_batch_3.json"
with open(output_file_path, "w") as file:
  json.dump(recipes, file, indent=4)
  print(f"health score in recipes has been saved")
